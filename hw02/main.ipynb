# %% [markdown]
# **Навигация по уроку**
#
# 1. [Введение в Python. Синтаксис](https://colab.research.google.com/drive/1YBLgd6tZYlkhwpnEc4IM8tVnewLUnlUO#scrollTo=yqZjRAldfz_L)
# 2. [Практика кода](https://colab.research.google.com/drive/1m-Ph90c-9S_gZchdG1ARoY2YjMTryKkl#scrollTo=UdxWiGmA63K2)
# 3. Домашняя работа

# %% [markdown]
# В домашней работе необходимо, используя знания теоретической части занятия и полученные практические навыки, решить, представленные ниже задачи. Для этого необходимо скопировать Блокнот (см. раздел 1.1.), решить в нем все задач, открыть общий доступ к Блокноту ((см. раздел 1.1.) и отправить ссылку на Блокнот куратору на проверку. Для прохождения урока необходимо решить минимум 2 задачи. Желаем удачи!

# %% [markdown]
# ## Задача 1. Приветствие.

# %% [markdown]
# **Условие.** Напишите программу, запрашивающую у пользователя его имя. В ответ
# на ввод на экране должно появиться приветствие с обращением по имени,
# введенному с клавиатуры ранее.

# %%
#Напишите свое решение

# спрашиваем имя
name = input('Как Вас зовут? ')
# выводим приветствие
print(f"Приветствую, {name}!")

#вариант без форматирования
print('Приветствую,', name,'!')
# Out:
# Как Вас зовут? 1
# Приветствую, 1!
# Приветствую, 1 !

# %% [markdown]
# ## Задача 2. Сувениры и безделушки.

# %% [markdown]
# **Условие.** Интернет-магазин занимается продажей различных сувениров и безделушек. Каждый сувенир весит 75 г, а безделушка – 112 г. Напишите программу, запрашивающую у пользователя количество тех и других покупок,
# после чего выведите на экран общий вес посылки.

# %%
#Напишите свое решение

#указание веса сувениров
suv_weight = 75
bezd_weight = 112

#запрос количества покупок
suv_buy = int(input('сколько хотите купить сувениров? '))
bezd_buy = int(input('сколько хотите купить безделушек? '))

#подсчет веса
total_weight = suv_weight * suv_buy + bezd_weight * bezd_buy

#вывод
print(f'Вам понадобится носильщик, чтобы унести посылку {total_weight} грамм')
# Out:
# сколько хотите купить сувениров? 5
# сколько хотите купить безделушек? 12
# Вам понадобится носильщик, чтобы унести посылку 1719 грамм

# %% [markdown]
# ## Задача 3. Сложные проценты

# %% [markdown]
# **Условие.** Представьте, что вы открыли в банке сберегательный счет под 4 % годовых. Проценты банк рассчитывает в конце года и добавляет к сумме счета.
# Напишите программу, которая запрашивает у пользователя сумму первоначального депозита, после чего рассчитывает и выводит на экран сумму
# на счету в конце первого, второго и третьего годов. Все суммы должны
# быть округлены до двух знаков после запятой.

# %%
#Напишите свое решение

#указание ставки (не понадобилось, но можно сделать формулой)
#s = 4

#запрос суммы
depo = float(input('укажите сумму взноса: '))

#расчет суммы в конце периодов (перебором; по сути можно было бы и циклом, но сейчас не помню их)
depo1 = depo * 1.04
depo2 = depo1 * 1.04
depo3 = depo2 * 1.04

#вывод
print ('Ваш депозит в конце периода составит', '1 год - %.2f' % depo1, '2 год - %.2f' % depo2, '3 год - %.2f' % depo3, sep = '\n')

#  ВОПРОС
# при таком виде записи возникает ошибка. Как можно было записать в подобном виде (сначала текст с форматированием, потом в одних скобках переменные для подставления, и в конце сепаратор), чего не хватило в моей записи с ошибкой?)
# print ('Ваш депозит в конце периода составит', '1 год - %.2f', '2 год - %.2f', '3 год - %.2f' % (depo1, depo2, depo3), sep = '\n')
# TypeError: not all arguments converted during string formatting
# попробовал поставить скобки на весь текст вывода print(('текст', 'текст', 'текст')%(переменные), sep), там тоже ошибка, но другая
# Out:
# укажите сумму взноса: 5000
# Ваш депозит в конце периода составит
# 1 год - 5200.00
# 2 год - 5408.00
# 3 год - 5624.32

# %% [markdown]
# ## Задача 4. Арифметика

# %% [markdown]
# **Условие.** Создайте программу, которая запрашивает у пользователя два целых числа a и b, после чего выводит на экран результаты следующих математических операций:
# * сумма a и b;
# * разница между a и b;
# * произведение a и b;
# * частное от деления a на b;
# * остаток от деления a на b;
# * десятичный логарифм числа a;
# * результат возведения числа a в степень b.

# %%
#Напишите свое решение

#импорт логарифма
from math import log10

#запрос чисел
a = int(input('введите целое число a: '))
b = int(input('введите целое число b: '))

#вывод вычислений
print('сумма a и b =', a+b)
print('разница между a и b =', a-b)
print('произведение a и b =', a*b)
print('частное от деления a на b =', a//b)
print('остаток от деления a на b =', a%b)
print('десятичный логарифм числа a =', log10(a))
print('результат возведения числа a в степень b = ', a**b )
# Out:
# введите целое число a: 5
# введите целое число b: 2
# сумма a и b = 7
# разница между a и b = 3
# произведение a и b = 10
# частное от деления a на b = 2
# остаток от деления a на b = 1
# десятичный логарифм числа a = 0.6989700043360189
# результат возведения числа a в степень b =  25

# %% [markdown]
# ## Задача 5. Размен

# %% [markdown]
# **Условие.** Представьте, что вы пишете программное обеспечение для автоматической кассы в  магазине самообслуживания. Одной из функций, заложенных в кассу, должен быть расчет сдачи в случае оплаты покупателем наличными.
# Напишите программу, которая будет запрашивать у пользователя сумму сдачи в копейках. После этого она должна рассчитать и вывести на экран, сколько и каких монет потребуется для выдачи указанной суммы, при условии что должно быть задействовано минимально возможное количество монет. Допустим, у нас есть в распоряжении монеты достоинством в 1, 5, 10, 50 копеек, а также в 1, 2 и 5 рублей.

# %%
#Напишите свое решение

#запрос суммы сдачи
cash = int(input('введите сумму сдачи в копейках: '))

#рассчет для монет 5, 2, 1 рублей и 50, 10, 5, 1 копеек
_5_rub = cash // (5*100)    #сколько 5 рублевых монет
ost = cash % (5*100)        #запомнить остаток после 5 рублевых монет
_2_rub = ost // (2*100)     #сколько 2 рублевых монет в остатке
ost = ost % (2*100)         #запомнить остаток после 2 рублевых монет и т.д.
_1_rub = ost // (1*100)
ost = ost % (1*100)
_50_cop = ost // 50
ost = ost % 50
_10_cop = ost // 10
ost = ost % 10
_5_cop = ost // 5
ost = ost % 5


#вывод
print('ваши монеты', f'5 рублей - {_5_rub}', f'2 рубля - {_2_rub}', f'1 рубль - {_1_rub}', f'50 копеек - {_50_cop}', f'10 копеек - {_10_cop}', f'5 копеек - {_5_cop}', f'1 копейка - {ost}', sep='\n')
# Out:
# введите сумму сдачи в копейках: 4156
# ваши монеты
# 5 рублей - 8
# 2 рубля - 0
# 1 рубль - 1
# 50 копеек - 1
# 10 копеек - 0
# 5 копеек - 1
# 1 копейка - 1

# %% [markdown]
# ## Задача 6. Вчерашний хлеб

# %% [markdown]
# **Условие.** Пекарня продает хлеб по 49 рублей за буханку. Скидка на вчерашний хлеб составляет 60 %. Напишите программу, которая будет запрашивать у пользователя количество приобретенных вчерашних буханок хлеба. В вывод на экран должны быть включены обычная цена за буханку, цена со скидкой и общая стоимость приобретенного хлеба. Все значения должны быть выведены на отдельных строках с соответствующими описаниями. Используйте для вывода формат с двумя знаками после запятой и 5-ю знакоместами.

# %%
#Напишите свое решение

#запрашиваем количество буханок
yest_bread = int(input('сколько вчерашних буханок вы купили? '))

#рассчет
price = 49                                    #актуальная цена
discount_price = price * 0.6                  #цена со скидкой
total_price = yest_bread * discount_price     #общая стоимость

#вывод с форматированием 5 знакомест, 2 знака после запятой, каждое значение с новой строки
print(f'актуальная цена за буханку - {price:5.2f} рублей', f'цена со скидкой - {discount_price:5.2f} рублей', f'стоимость вашей покупки - {total_price:5.2f} рублей', sep='\n')
# Out:
# сколько вчерашних буханок вы купили? 200
# актуальная цена за буханку - 49.00 рублей
# цена со скидкой - 29.40 рублей
# стоимость вашей покупки - 5880.00 рублей
